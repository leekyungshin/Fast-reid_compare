# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from util.visualization import show_images

dataset_path = os.path.join('/home/leekyungshin/Desktop/Nextlab/reid_onnx_deploy/preproccessed_img')
df = pd.read_csv('/home/leekyungshin/Desktop/Nextlab/reid_onnx_deploy/annotation/data.csv')
samples = df.groupby('direction').sample(10)

show_images(samples.iloc[0:10], dataset_path, 'back')
show_images(samples.iloc[10:20], dataset_path, "front")
show_images(samples.iloc[20:30], dataset_path, 'side')
